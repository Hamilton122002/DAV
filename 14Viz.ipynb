# %%
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("cereal.csv")
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
plt.bar(df['mfr'],df['calories'])
plt.title("Calories Bar Chart")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sb.lineplot(x='sodium',y='mfr', data=df)
plt.show()

# %%
plt.scatter(df['sugars'] ,df['carbo'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sb.lineplot(x='mfr', y='sodium', data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(df['sugars'])
plt.plot(df['fiber'])
plt.ylabel('Quantity')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(df['potass'])
plt.title('Histogram')
plt.show()

# %%
sb.barplot(x='mfr', y='rating', data= df, hue='vitamins')
plt.show()

# %%
from bokeh.plotting import figure, output_file, show
graph = figure(title = "Bokeh Scatter Plot")
graph.scatter(df['sodium'], df['fiber'])
show(graph)

# %%
fig = plt.figure(figsize = (10,7))
ax = plt.axes(projection = "3d")
ax.scatter3D(df['sodium'], df['potass'], df['sugars'])
plt.title("3d Scatter Plot")
plt.show()

# %%
sb.set(style='ticks', color_codes = True)
iris = sb.load_dataset("iris")
g = sb.pairplot(iris)
plt.show()

# %%
my_data = [300, 500, 700]
my_labels = 'Tasks Pending', 'Tasks Ongoing', 'Tasks Completed'
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%')
plt.title('My Tasks')
plt.axis('equal')
plt.show()

# %%
sb.countplot(x=df['mfr'], data = df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sb.pointplot(data = df, x=df['mfr'], y = df['potass'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.boxplot(by='mfr', column = ['sugars'], grid = False)
# Out:
# <AxesSubplot:title={'center':'sugars'}, xlabel='mfr'>

# %%
sb.set_style("whitegrid")
sb.boxplot(x='mfr', y='potass', data = df)
# Out:
# <AxesSubplot:xlabel='mfr', ylabel='potass'>

# %%
from matplotlib import pyplot
fig, ax = pyplot.subplots(figsize = (9, 7))
sb.violinplot(ax = ax, y = df['sugars'])
# Out:
# <AxesSubplot:ylabel='sugars'>

# %%
fig, ax = pyplot.subplots(figsize = (9, 7))
sb.violinplot(ax = ax, y = df['sodium'])
# Out:
# <AxesSubplot:ylabel='sodium'>

# %%
sb.swarmplot(data = df, x='rating')
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
sb.kdeplot(data=df, x='potass')
# Out:
# <AxesSubplot:xlabel='potass', ylabel='Density'>

# %%
sb.kdeplot(data=df, y='carbo')
# Out:
# <AxesSubplot:xlabel='Density', ylabel='carbo'>

# %%
dataset = pd.read_csv("Datasets/IRIS.csv")
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
plt.figure(figsize=(7,4))
sb.heatmap(iris.corr(),annot=True,cmap='summer')
# Out:
# <AxesSubplot:>
